# %% [markdown]
# # Setup

# %% [markdown]
# This notebook covers environment and prerequisite setup for Semantic Link Labs, including enabling XMLA endpoints and installing dependencies.

# %% [markdown]
# ### Enabling Semantic Link Labs

# %% [markdown]
# #### We are going to use the XMLA Endpoint (so make sure it is enabled!)
# 1. To enable it, click "Admin Portal":
#
#    <img src="https://raw.githubusercontent.com/edwardpcharles/presentations/main/Images/admin_portal.png" alt="Admin Portal" width="300" />
#
# 2. Search for XMLA:
#
#    <img src="https://raw.githubusercontent.com/edwardpcharles/presentations/main/Images/search_for_xmla.png" alt="Searching for XMLA" width="300" />
#
# 3. Enable "Allow XMLA endpoints and Analyze in Excel with on-premises semantic models":
#
#    <img src="https://raw.githubusercontent.com/edwardpcharles/presentations/main/Images/enable_xmla_main.png" alt="Enable XMLA Setting" width="300" />
#
# 4. Click "Capacity settings":
#
#    <img src="https://raw.githubusercontent.com/edwardpcharles/presentations/main/Images/capacity_settings.png" alt="Click a Capacity Setting" width="300" />
#
# 5. Find your Capacity and select it:
#
#    <img src="https://raw.githubusercontent.com/edwardpcharles/presentations/main/Images/select_a_capacity.png" alt="Select a Capacity" width="300" />
#
# 6. Expand "Power BI workloads":
#
#    <img src="https://raw.githubusercontent.com/edwardpcharles/presentations/main/Images/expand_powerbi.png" alt="Expand Power BI Workloads" width="300" />
#
# 7. Set XMLA Endpoing to "Read Write":
#
#    <img src="https://raw.githubusercontent.com/edwardpcharles/presentations/main/Images/makesure_xmla_endpoint.png" alt="Expand Power BI Workloads" width="300" />

# %% [markdown]
# #### Install Semantic Link Labs. You have two options:

# %% [markdown]
# ##### Create an Environment
# 1. Click "+ New item" Then Click Environment:
#
#     <img src="https://raw.githubusercontent.com/edwardpcharles/presentations/main/Images/new_enviornment.png" alt="How to Add a Enviornment" width="300" />
#
# 2. Add "semantic-link-labs" as a external repository and click "Publish":
#
#     <img src="https://raw.githubusercontent.com/edwardpcharles/presentations/main/Images/adding%20Semantic%20Link%20Labs.png" alt="Adding Semantic Link Labs" width="300" />
#
# 3. Select the "Envronment" you just created in a Notebook:
#
#     <img src="https://raw.githubusercontent.com/edwardpcharles/presentations/main/Images/select_the_enviornment.png" alt="Select the Environment" width="300" />

# %%
# Check to see if it installed Semantic Link Labs with the following code:
# !pip list | grep semantic-link-labs

# %% [markdown]
# ##### Install it directly in to the notebook session with a pip command

# %%
#install Semantic Link Labs
# %pip install semantic-link-labs
